# %%
# %sql
select status, count(status) as Status_count from project1 group by status;

# %%
# %sql
select status, year(lca_case_submit) as year, count(status) as count from project1 group by status, year(lca_case_submit);

# %%
# %sql
select lca_case_wage_rate_from, lca_case_wage_rate_unit, year(decision_date) as year from project1 where lca_case_wage_rate_unit = 'YEAR';

# %%
# %sql
select year(decision_date) as year, lca_case_wage_rate_from as average from project1 where lca_case_wage_rate_unit = 'Year';

# %%
# %sql
select lca_case_employer_state, count(lca_case_employer_state) as State_Count from project1 group by lca_case_employer_state;

# %%
# %sql
select lca_case_employer_state, count(status) as Denied_Count from project1 where status='DENIED' group by lca_case_employer_state, status;

# %%
# %sql
select lca_case_employer_state, count(status) as Australia_Data from project1 where visa_class = 'E-3 Australian' group by lca_case_employer_state, status;

# %%
# %sql
select lca_case_employer_postal_code from project1 where lca_case_employer_state = 'CA';
